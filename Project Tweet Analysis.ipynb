# %% [markdown]
# # Project Tweet Analysis

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
import pandas as pd
from scipy.special import softmax
import csv
import urllib.request
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# Preprocess text (username and link placeholders)
def preprocess(text):
    new_text = []


    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# Tasks:
# emoji, emotion, hate, irony, offensive, sentiment
# stance/abortion, stance/atheism, stance/climate, stance/feminist, stance/hillary

task='sentiment'
MODEL = f"cardiffnlp/twitter-roberta-base-{task}"

tokenizer = AutoTokenizer.from_pretrained(MODEL)

# %%
# download label mapping
labels=[]
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels = [row[1] for row in csvreader if len(row) > 1]

# PT
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
model.save_pretrained(MODEL)

# %%
tweets = pd.read_csv('tweets.csv')

# %%
tweets.columns = ['user', 'datetime', 'content']

# %%
tweets
# Out:
#                user             datetime  \
# 0       repdonyoung  2020-12-07 16:46:19
# 1       repdonyoung  2020-12-04 20:52:29
# 2       repdonyoung  2020-12-04 20:52:29
# 3       repdonyoung  2020-12-04 20:52:29
# 4       repdonyoung  2020-12-04 20:52:29
# ...             ...                  ...
# 61533  RepLizCheney  2020-04-09 00:52:31
# 61534  RepLizCheney  2020-04-08 22:44:33
# 61535  RepLizCheney  2020-04-07 21:39:30
# 61536  RepLizCheney  2020-04-07 20:12:41
# 61537  RepLizCheney  2020-04-07 15:21:03
#
#                                                  content
# 0      Today, we remember the courageous souls lost 7...
# 1      I will continue working with my colleagues and...
# 2      As co-founder of the House Cannabis Caucus, I ...
# 3      Since Alaska legalized marijuana, I have heard...
# 4      I am a passionate supporter of a states’ right...
# ...                                                  ...
# 61533  Click here for the latest updates on the feder...
# 61534  Wishing everyone observing tonight a happy Pas...
# 61535  Since the launch of the Paycheck Protection Pr...
# 61536  We need to help Americans who are hurting and ...
# 61537  Americans always rise to meet unexpected chall...
#
# [61538 rows x 3 columns]

# %%
tweets = tweets[tweets.user != 'housedemocrats']
tweets = tweets[tweets.user != 'housegop']

# %%
tweets
# Out:
#                user             datetime  \
# 0       repdonyoung  2020-12-07 16:46:19
# 1       repdonyoung  2020-12-04 20:52:29
# 2       repdonyoung  2020-12-04 20:52:29
# 3       repdonyoung  2020-12-04 20:52:29
# 4       repdonyoung  2020-12-04 20:52:29
# ...             ...                  ...
# 61533  RepLizCheney  2020-04-09 00:52:31
# 61534  RepLizCheney  2020-04-08 22:44:33
# 61535  RepLizCheney  2020-04-07 21:39:30
# 61536  RepLizCheney  2020-04-07 20:12:41
# 61537  RepLizCheney  2020-04-07 15:21:03
#
#                                                  content
# 0      Today, we remember the courageous souls lost 7...
# 1      I will continue working with my colleagues and...
# 2      As co-founder of the House Cannabis Caucus, I ...
# 3      Since Alaska legalized marijuana, I have heard...
# 4      I am a passionate supporter of a states’ right...
# ...                                                  ...
# 61533  Click here for the latest updates on the feder...
# 61534  Wishing everyone observing tonight a happy Pas...
# 61535  Since the launch of the Paycheck Protection Pr...
# 61536  We need to help Americans who are hurting and ...
# 61537  Americans always rise to meet unexpected chall...
#
# [52520 rows x 3 columns]

# %%
def classify(row):
    text = preprocess(row['content'])
    encoded_input = tokenizer(text, return_tensors='pt')
    output = model(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    for i in range(scores.shape[0]):
        l = labels[ranking[i]]
        s = scores[ranking[i]]
        if l == 'positive':
            positive = scores[ranking[i]]
        elif l == "neutral":
            neutral = scores[ranking[i]]
        elif l == "negative":
            negative = scores[ranking[i]]
    return positive, neutral, negative

# %%
n = 500  #chunk row size
tweets_df = [tweets[i:i+n] for i in range(0,tweets.shape[0],n)]

# %%
tweets_final = pd.DataFrame()
for chunk in tweets_df:
    chunk['positive'], chunk['neutral'], chunk['negative'] = zip(*chunk.apply(classify, axis=1))
    #tweets_final[['positive', 'neutral', 'negative']] = tweets_final.apply(lambda row: classify(row), axis=1)
    tweets_final = tweets_final.append(chunk)
    print("Processed chunk of 500")
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500
# Processed chunk of 500

# %%
tweets_final.to_csv(r'./tweets_final.csv',index=False)

# %%
tweets_final
# Out:
#                user             datetime  \
# 0       repdonyoung  2020-12-07 16:46:19
# 1       repdonyoung  2020-12-04 20:52:29
# 2       repdonyoung  2020-12-04 20:52:29
# 3       repdonyoung  2020-12-04 20:52:29
# 4       repdonyoung  2020-12-04 20:52:29
# ...             ...                  ...
# 61533  RepLizCheney  2020-04-09 00:52:31
# 61534  RepLizCheney  2020-04-08 22:44:33
# 61535  RepLizCheney  2020-04-07 21:39:30
# 61536  RepLizCheney  2020-04-07 20:12:41
# 61537  RepLizCheney  2020-04-07 15:21:03
#
#                                                  content  positive   neutral  \
# 0      Today, we remember the courageous souls lost 7...  0.680861  0.277483
# 1      I will continue working with my colleagues and...  0.800538  0.195412
# 2      As co-founder of the House Cannabis Caucus, I ...  0.586395  0.393374
# 3      Since Alaska legalized marijuana, I have heard...  0.015326  0.282598
# 4      I am a passionate supporter of a states’ right...  0.220732  0.544757
# ...                                                  ...       ...       ...
# 61533  Click here for the latest updates on the feder...  0.073239  0.907484
# 61534  Wishing everyone observing tonight a happy Pas...  0.980894  0.018106
# 61535  Since the launch of the Paycheck Protection Pr...  0.443877  0.550937
# 61536  We need to help Americans who are hurting and ...  0.550615  0.416058
# 61537  Americans always rise to meet unexpected chall...  0.945573  0.049896
#
#        negative
# 0      0.041656
# 1      0.004050
# 2      0.020230
# 3      0.702076
# 4      0.234510
# ...         ...
# 61533  0.019278
# 61534  0.001000
# 61535  0.005186
# 61536  0.033327
# 61537  0.004531
#
# [52520 rows x 6 columns]

# %%
tweets_final = pd.read_csv('./tweets_final.csv')

# %%
us_reps
# Out:
#                user             datetime  \
# 0       repdonyoung  2020-12-07 16:46:19
# 1       repdonyoung  2020-12-04 20:52:29
# 2       repdonyoung  2020-12-04 20:52:29
# 3       repdonyoung  2020-12-04 20:52:29
# 4       repdonyoung  2020-12-04 20:52:29
# ...             ...                  ...
# 52515  RepLizCheney  2020-04-09 00:52:31
# 52516  RepLizCheney  2020-04-08 22:44:33
# 52517  RepLizCheney  2020-04-07 21:39:30
# 52518  RepLizCheney  2020-04-07 20:12:41
# 52519  RepLizCheney  2020-04-07 15:21:03
#
#                                                  content  positive   neutral  \
# 0      Today, we remember the courageous souls lost 7...  0.680861  0.277483
# 1      I will continue working with my colleagues and...  0.800538  0.195412
# 2      As co-founder of the House Cannabis Caucus, I ...  0.586395  0.393374
# 3      Since Alaska legalized marijuana, I have heard...  0.015326  0.282598
# 4      I am a passionate supporter of a states’ right...  0.220732  0.544757
# ...                                                  ...       ...       ...
# 52515  Click here for the latest updates on the feder...  0.073239  0.907484
# 52516  Wishing everyone observing tonight a happy Pas...  0.980894  0.018106
# 52517  Since the launch of the Paycheck Protection Pr...  0.443877  0.550936
# 52518  We need to help Americans who are hurting and ...  0.550615  0.416058
# 52519  Americans always rise to meet unexpected chall...  0.945573  0.049896
#
#        negative
# 0      0.041656
# 1      0.004050
# 2      0.020230
# 3      0.702076
# 4      0.234510
# ...         ...
# 52515  0.019278
# 52516  0.001000
# 52517  0.005186
# 52518  0.033327
# 52519  0.004531
#
# [52520 rows x 6 columns]

# %%
tweets_small
# Out:
#                 user             datetime  \
# 0        repdonyoung  2020-12-07 16:46:19
# 1        repdonyoung  2020-12-04 20:52:29
# 2        repdonyoung  2020-12-04 20:52:29
# 3        repdonyoung  2020-12-04 20:52:29
# 4        repdonyoung  2020-12-04 20:52:29
# ..               ...                  ...
# 495  RepMikeRogersAL  2020-09-02 13:25:37
# 496  RepMikeRogersAL  2020-09-02 00:38:28
# 497  RepMikeRogersAL  2020-09-02 00:37:45
# 498  RepMikeRogersAL  2020-09-01 17:56:50
# 499  RepMikeRogersAL  2020-09-01 12:14:36
#
#                                                content  positive   neutral  \
# 0    Today, we remember the courageous souls lost 7...  0.680861  0.277483
# 1    I will continue working with my colleagues and...  0.800538  0.195412
# 2    As co-founder of the House Cannabis Caucus, I ...  0.586395  0.393374
# 3    Since Alaska legalized marijuana, I have heard...  0.015326  0.282598
# 4    I am a passionate supporter of a states’ right...  0.220732  0.544757
# ..                                                 ...       ...       ...
# 495  Montgomery County! Have you completed your cen...  0.174953  0.813216
# 496          “Mostly Peaceful” https://t.co/nyjywv836v  0.433050  0.545009
# 497  Thank you @realdonaldtrump for showing some re...  0.971366  0.027205
# 498  Exciting stuff coming tomorrow! #AlabamaCounts...  0.985020  0.014078
# 499  👋🏻Lee County! Make sure your voice is heard. R...  0.465553  0.519252
#
#      negative
# 0    0.041656
# 1    0.004050
# 2    0.020230
# 3    0.702076
# 4    0.234510
# ..        ...
# 495  0.011831
# 496  0.021941
# 497  0.001429
# 498  0.000903
# 499  0.015195
#
# [500 rows x 6 columns]

# %%
tweets

# %%
tweets.to_csv(r'./tweets_annotated.csv',index=False)

# %% [markdown]
# ## Model Testing

# %%
text = """



"""
text = preprocess(text)
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
scores = output[0][0].detach().numpy()
scores = softmax(scores)

ranking = np.argsort(scores)
ranking = ranking[::-1]


# # TF
# model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
# model.save_pretrained(MODEL)

# text = "Good night 😊"
# encoded_input = tokenizer(text, return_tensors='tf')
# output = model(encoded_input)
# scores = output[0][0].numpy()
# scores = softmax(scores)
# Out:
# array([0, 1, 2])

# %%
scores[ranking[2]]
if labels[ranking[1]] == 'neutral':
    print(labels[ranking[1]])

# %%
    for i in range(scores.shape[0]):
        l = labels[ranking[i]]
        s = scores[ranking[i]]
        print(f"{i+1}) {l} {np.round(float(s), 4)}")
